# %% [markdown]
# <a href="https://colab.research.google.com/github/AleksandrPshonniy/Bulat777/blob/main/%D0%B4%D0%BE%D0%BC%D0%B0%D1%88%D0%BA%D0%B0%206.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string

input_str = input("enter two letters:")
letters = input_str.split("-")
if len(letters)!= 2 or len(letters[0])!=1 or len(letters[1])!=1:
   print("please enter two letters")
else:
    start_letter = letters[0]
    end_letter = letters[1]
    all_letters = string.ascii_letters
    start_index = all_letters.index(start_letter)
    end_index = all_letters.index(end_letter)
# Out:
# enter two letters:a-h
